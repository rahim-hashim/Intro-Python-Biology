# %% [markdown]
# # Intro to Python
# ## Lesson 1: Foudations
#
# **Date:** July 2, 2021<br>
# **Programmer:** Rahim Hashim<br>
# **Goal:** The goal of this lesson is to get familiar with Google Colab, executing code, data types, and functions.

# %% [markdown]
# ***
# ## STEP 1: The Rules of Python
#
# ### Before Starting
# A few quick things to know about Python.
#
# * **Grey shaded boxes are code, all the other text is that won't run.**
# You can double click the white to see how the text is written in [Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=w86a4I4fmkvD) format
# * **To compile code**&mdash;meaning send the message to the system's compiler to execute&mdash;you have to click **SHIFT+ENTER** at the same time. It works for both Markdown and Code.
#   * cmd + m + y will convert a markdown cell to a code cell
#   * cmd + m + m will convert a code cell to a text cell
#
# * **Indentation matters when you code:** The two code blocks below are registered differently from one another&mdash;
#
# >if a \> b <br>
# >then print a
#
# ..
#
# >if a \> b <br>
# >>then print a
#
# * The order of execution for cells matters!
#
# The lower one is right, but you'll see that once we start using IF and THEN. You'll also see quickly that Python sounds very English-y. You can code similarly to how you think/speak, which is a huge benefit.
#
# Now, to get us started on assigning variables!

# %% [markdown]
# ***
# ## STEP 2: Math
#
# In Python, 2 + 2 is called an expression, which is the most basic kind of programming instruction in the language.
#
# Expressions consist of values (such as 2) and operators (such as +), and they can always evaluate (that is, reduce) down to a single value. That means you can use expressions anywhere in Python code that you could also use a value.

# %%
2+2
# Out:
# 4

# %% [markdown]
# In the previous example, 2 + 2 is evaluated down to a single value, 4. A single value with no operators is also considered an expression, though it evaluates only to itself, as shown here:

# %%
2
# Out:
# 2

# %%
(5-1) * ((7+1)) / (3 - 1)
# Out:
# 16.0

# %%
8/2
# Out:
# 4.0

# %%
5 + # error
# Out:
#   File "<ipython-input-13-cc17ac754b68>", line 1
#     5 + # error
#                ^
# SyntaxError: invalid syntax

# %%
42 + 5 + * 2 # error
# Out:
#   File "<ipython-input-15-16e07b76f178>", line 1
#     42 + 5 + * 2
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Note: 2+2 and 2.0+2.0 result in different outputs, which we'll get to in a little bit

# %%
2 + 2
# Out:
# 4

# %%
2.0 + 2.0
# Out:
# 4.0

# %% [markdown]
# ***
# ## Step 3: STRINGS
#
# ### Lettered Expressions
#
# Think of a word as a list of letters, in the same way above we had lists of numbers. In Python, a list of letters is called a **string**.

# %%
'a' + 'a'
# Out:
# 'aa'

# %%
'a' + 'b #error
# Out:
#   File "<ipython-input-7-e719427f7031>", line 1
#     'a' + 'b
#             ^
# SyntaxError: EOL while scanning string literal

# %%
'Rahim' + 'Hashim'
# Out:
# 'RahimHashim'

# %%
'Rahim' + ' ' + 'Hashim'
# Out:
# 'Rahim Hashim'

# %%
'Rahim' + 5 # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0c51376e0739> in <module>()
# ----> 1 'Rahim' + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
'Rahim' + '5'
# Out:
# 'Rahim5'

# %%
'Rahim' * 5
# Out:
# 'RahimRahimRahimRahimRahim'

# %% [markdown]
# ***
# ## Step 4: BOOLEANS
#
# Booleans are a forth data type stores either True or False. That is it.
#
# In Python, as we've used above, **=** is to assign a variable to a value. However, if you want to see if two things are equal, you must use **==**, which results in a boolean True or False. These will come in handy when comparing values (if x == y, then ...)

# %%
True == True
# Out:
# True

# %% [markdown]
# Now, you'll notice that for the first time, an expression evaluated to a Boolean value, which for those who aren't familiar, is based on Boolean logic. Try it out by starting to type True, and you'll notice that it changes color, which means that in Python syntax, it has inherent meaning

# %%
True == True
True == (not True)
# Out:
# False

# %% [markdown]
# ### Comparison Operators

# %%
6 > 3
# Out:
# True

# %% [markdown]
# ***
# ## STEP 5: VARIABLES
#
# ### Number Variables
#
# Setting a variable is pretty similar to most other programming languages. In Python, the type of a variable is flexible, meaning you don't have to assign it before you use it.
#
# Example:

# %%
# Assigning variables
a = 9
b = 10

# %% [markdown]
# A few things to note &mdash;
#
# 0. Variables must be assigned above where they are used
# 1. Unlike previous cells, nothing printed when you assigned a variable
# 2. \# starts a comment, which is why you see it in that greenish color for the text in line 1. It means it it's just text and won't run when you start code
# 3. When you run code, the left margin bracket has a * (i.e. [*]) which means the code is running. It will show a number (i.e. [1]) when it is done

# %%
a
b
# Out:
# 10

# %% [markdown]
# There's something different about this cell. What is it?...
#
# If you've noticed, this is the first multi-lined cell that we've used before. And which line was executed? Both. Which line was shown in the output? Only the last

# %% [markdown]
# ### Lettered Variables

# %%
name = 'Rahim' # 1_name = 'Rahim' would give you an error

# %% [markdown]
# ***
# ## Step 6: FUNCTIONS
# ### Print
#
# In order to control the output manually, use the built-in function called `print` which displays variables as text. To print, provide call the function using parenthesis containing the variable you want to print:
# ```
# print()
# ```

# %% [markdown]
# If you'll notice, when you write a function, the color of the font changes ONLY when you use the paranthesis, and also, on Google Colab specifically, you get a bit of information about the function.
# * keyword arguments vs. variable arguments

# %%
print(name)
# Out:
# Rahim

# %%
print(nmae) # error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-624abc7de6fc> in <module>()
# ----> 1 print(nmae) # error
#
# NameError: name 'nmae' is not defined

# %%
print(name, 'is', 'cool')
# Out:
# Rahim is cool

# %% [markdown]
# You add, subtract, multiply, etc. numbers and strings the exact same way. You assign strings by including letters and numbers within quotes (single or double work).

# %%
x = 5
y = 10

xy_sum = x + y # <- now will equal 15
print(xy_sum)
# Out:
# 15

# %%
print(name, 'is', a, 'years old')
# Out:
# Rahim is 9 years old

# %% [markdown]
# ### Type
#
# Every value in a program has a specific **type**
# * **Integer (int):** represents positive or negative whole numbers like 3 or -512
# * **Floating point number (float):** represents real numbers like 3.14159 or -2.5
# * **Character string (usually called “string”, str):** text
#   * Written in either single quotes or double quotes (as long as they match)
#   The quote marks aren’t printed when the string is displayed.

# %% [markdown]
# Types are important to understand, because the variables that you store always have property, depending on the type. We've been through two types already&mdash;basic numbers, which we will call **int** meaning integers (or whole numbers), and **strings** (or words). An example where types are really important is when you introduce a third type, which are numbers that include decimals, which in Python is called **float**.
#
# The below example shows how the output depends greatly on the types of variables you are assigning.

# %%
number = 2.0
print(type(number))
# Out:
# <class 'float'>

# %% [markdown]
# As you can see, you can use `int()`, `str()`, and `float()` just like you use other Python functions to jump between types.

# %%
int(2.0)
# Out:
# 2

# %% [markdown]
# Trying to perform certain arithmetic operations such as division between two different types&mdash;string '10' and int 3&mdash;will give you a TypeError, so be extra deliberate about what type you set a variable as when you use it. A list of common Python [Mathematical Operators](https://en.wikibooks.org/wiki/Python_Programming/Basic_Math) would be helpful to review.
#
# If the conversion doesn’t make sense, however, an error message will occur.

# %%
print('string to float:', float('Hello world!')) # error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5859c8720772> in <module>()
# ----> 1 print('string to float:', float('Hello world!')) # error
#
# ValueError: could not convert string to float: 'Hello world!'

# %% [markdown]
# ### Len
#
# Use the built-in function `len` to find the length of a string

# %%
len(name) # test
# Out:
# 5

# %% [markdown]
# ***
# ## Step 7: LISTS

# %% [markdown]
# A few things about lists:
# 1. A list of numbers (like the variable *b* above) is separated by commas
# 2. Indexing the list starts at 0
# 3. You can access each of these elements individually using a bracket
# 4. Variable names are case sensitive (a vs. A are different variables)

# %%
b = [2, 8, 24]
c = [12.2, 4.6]

# %%
b[0]
# Out:
# 2

# %%
b[1]
# Out:
# 8

# %%
a[0] # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b35c04188056> in <module>()
# ----> 1 a[0] # error
#
# TypeError: 'int' object is not subscriptable

# %%
c[1]
# Out:
# 4.6

# %%
c[2] # error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-c345d4a9f72d> in <module>()
# ----> 1 c[2] # error
#
# IndexError: list index out of range

# %%
value_number = 10
value_string = '10'

print(value_number == value_number) # test
print(value_number == value_string) # test
# Out:
# True
# False

# %% [markdown]
# ### Practice Problem

# %%
# practice during break
tip_percent = input('tip percent?')
bill = input('bill: $ ')
tip_amount = float(bill) * float(tip_percent)/100 # float is necessary to convert str to a mathematical value 

print('Tip: $', tip_amount)
total_bill = float(bill) * (1+(float(tip_percent)/100))
print('Total: $', total_bill)
# Out:
# tip percent?20
# bill: $ 50
# Tip: $ 10.0
# Total: $ 60.0

# %% [markdown]
# ### Slice
#
# An item in a list is called an **element**.
# * Whenever we treat a string as if it were a list, the string’s elements are its individual characters
# A part of a string is called a **substring**.
#
#
# A slice is a part of a string (or, more generally, any list-like thing).
# * We take a slice by using [start:stop], where start is replaced with the index of the first element we want and stop is replaced with the index of the element just after the last element we want
# * Mathematically, you might say that a slice selects [start:stop)
# * Taking a slice does not change the contents of the original string...instead, the slice is a copy of part of the original string

# %%
atom_name = 'sodium'
print(atom_name[0:3]) # test
# Out:
# sod

# %%
today = ['06-02-2021']; tomorrow = ['06-03-2021']
dates = ['06-01-2021'] + today + tomorrow
print(dates)
# Out:
# ['06-01-2021', '06-02-2021', '06-03-2021']

# %%
dates = ['06-01-2021'] + [today] + [tomorrow]
print(dates[1][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-9b9ee489c378> in <module>()
#       1 dates = ['06-01-2021'] + [today] + [tomorrow]
# ----> 2 print(dates[1][1])
#
# IndexError: list index out of range

# %%
dates = ['06-01-2021'] + [today + tomorrow]
print(dates[1][1])
# Out:
# 06-03-2021

# %% [markdown]
# ***
# ## Step 8: ADDITIONAL FUNCTIONS
# ### max, min, sum, round

# %%
number_list = [6.25, 8, 1.5, 15, 2, 5, 12, 3]
print(max(number_list))
print(min(number_list))
print(sum(number_list))
print(round(number_list))
# Out:
# 15
# 1.5
# 52.7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8ffd1af72ba1> in <module>()
#       3 print(min(number_list))
#       4 print(sum(number_list))
# ----> 5 print(round(number_list))
#
# TypeError: type list doesn't define __round__ method

# %%
print(round(number_list[0], 1))

# %% [markdown]
# ***
# ## STEP 9: SUMMARY
#
# ### 1. [Data Types](https://www.tutorialspoint.com/python/python_variable_types.htm)
#  * Integers: `int()`
#  * Floats: `float()`
#  * Strings: `str()` or `''` or `""`
#  * List: `list()` or `[]`
#  * Booleans: `True` or `False`
#  * Tuples: `tuple()` or `()`
#
# ### 2. [Math and Logic](https://www.tutorialspoint.com/python/python_basic_operators.htm)
#  * Arithmetic Operators: `=` | `+` | `-` | `*` | `/` | `**`
#  * Comparison Operators: `==` | `!=` | `<>` | `>` | `<` | `>=` | `<=`
#  * Logical Operators: `and` | `or` | `not`
#  * Membership Operators: `in` | `not in`
#  * Identity Operators: `is` | `is not`
#
# ### 3. [Functions](https://www.tutorialspoint.com/python/python_basic_syntax.htm)
#  * Convert Datatypes: `int` | `str` | `float`
#  * Indexing:
#     * `example_list[start:end]`
#     * `example_str[start:end]`
#  * Print: `print()`
#  * Type: `type()`
#  * Len: `len()`
